# %%
# !git clone https://github.com/soCzech/TransNet
# Out:
# Cloning into 'TransNet'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 27 (delta 0), reused 0 (delta 0), pack-reused 24
# Unpacking objects: 100% (27/27), done.

# %%
# !pip3 install --upgrade --force-reinstall tensorflow-gpu==1.15.0 
# !pip install protobuf==3.20.*
# !pip install ffmpeg-python

# %%
# !gdown --id 1bcAds2qz0rLDvwSCXFmaNozHWVu1DKj6

# %%
# %cd TransNet
# Out:
# /media/nhattuong/Data/TranseNet/TransNet

# %%
import ffmpeg
import numpy as np
import tensorflow as tf

from transnet import TransNetParams, TransNet
from transnet_utils import draw_video_with_predictions, scenes_from_predictions

import glob
import os
import cv2

# %%
# initialize the network
params = TransNetParams()
params.CHECKPOINT_PATH = "./model/transnet_model-F16_L3_S2_D256"

net = TransNet(params)
# Out:
# WARNING:tensorflow:From /media/nhattuong/Data/TranseNet/TransNet/transnet.py:20: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# [TransNet] Creating ops.
# WARNING:tensorflow:From /media/nhattuong/Data/TranseNet/TransNet/transnet.py:31: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /media/nhattuong/Data/TranseNet/TransNet/transnet.py:37: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#            Input (?, ?, 27, 48, 3)
#            SDDCNN_1
# WARNING:tensorflow:From /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2022-11-11 02:08:50.424538: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-11-11 02:08:50.445043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-11 02:08:50.445151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: NVIDIA GeForce RTX 3090 Ti major: 8 minor: 6 memoryClockRate(GHz): 1.95
# pciBusID: 0000:01:00.0
# 2022-11-11 02:08:50.445226: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudart.so.10.0'; dlerror: libcudart.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64
# 2022-11-11 02:08:50.445261: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcublas.so.10.0'; dlerror: libcublas.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64
# 2022-11-11 02:08:50.445287: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcufft.so.10.0'; dlerror: libcufft.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64
# 2022-11-11 02:08:50.445313: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcurand.so.10.0'; dlerror: libcurand.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64
# 2022-11-11 02:08:50.445340: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusolver.so.10.0'; dlerror: libcusolver.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64
# 2022-11-11 02:08:50.445372: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcusparse.so.10.0'; dlerror: libcusparse.so.10.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64
# 2022-11-11 02:08:50.445399: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcudnn.so.7'; dlerror: libcudnn.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/nhattuong/anaconda3/envs/transnet/lib/python3.7/site-packages/cv2/../../lib64:/usr/local/cuda-11.3/lib64
# 2022-11-11 02:08:50.445403: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1641] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-11-11 02:08:50.446399: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-11-11 02:08:50.453115: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3609600000 Hz
# 2022-11-11 02:08:50.454389: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1b34b80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-11-11 02:08:50.454410: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-11-11 02:08:50.537423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-11 02:08:50.537783: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x47e36a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-11-11 02:08:50.537804: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090 Ti, Compute Capability 8.6
# 2022-11-11 02:08:50.538068: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-11-11 02:08:50.538074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]
#            > DDCNN_1 (?, ?, 27, 48, 64)
#            > DDCNN_2 (?, ?, 27, 48, 64)
#            MaxPool (?, ?, 13, 24, 64)
#            SDDCNN_2
#            > DDCNN_1 (?, ?, 13, 24, 128)
#            > DDCNN_2 (?, ?, 13, 24, 128)
#            MaxPool (?, ?, 6, 12, 128)
#            SDDCNN_3
#            > DDCNN_1 (?, ?, 6, 12, 256)
#            > DDCNN_2 (?, ?, 6, 12, 256)
#            MaxPool (?, ?, 3, 6, 256)
#            Flatten (?, ?, 4608)
#            Dense (?, ?, 256)
#            Logits (?, ?, 2)
#            Predictions (?, ?)
# [TransNet] Network built.
# WARNING:tensorflow:From /media/nhattuong/Data/TranseNet/TransNet/transnet.py:72: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# [TransNet] Found 4614850 trainable parameters.
# WARNING:tensorflow:From /media/nhattuong/Data/TranseNet/TransNet/transnet.py:77: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Restoring parameters from ./model/transnet_model-F16_L3_S2_D256
# [TransNet] Parameters restored from 'transnet_model-F16_L3_S2_D256'.

# %%
################# Config Folder #################
video_paths = sorted(glob.glob('/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/*.mp4'))
des_path = '/media/nhattuong/Data/TranseNet/TransNet_Database/KeyFramesC02_V02/'
#################################################

# os.makedirs(des_path, exist_ok=True)

for video_path in video_paths:
    folder_name = video_path.split('/')[-1].replace( '.mp4','')

    test_folder = int(folder_name.replace('C02_V',''))
    print(test_folder)
    # if test_folder <= 244 or test_folder==253 or test_folder==271:
    #     print(f"Skip {folder_name}")
    #     continue

    folder_path = des_path + f'{folder_name}'
    os.mkdir(folder_path)

    # export video into numpy array using ffmpeg
    video_stream, err = (
        ffmpeg
        .input(video_path)
        .output('pipe:', format='rawvideo', pix_fmt='rgb24', s='{}x{}'.format(params.INPUT_WIDTH, params.INPUT_HEIGHT))
        .run(capture_stdout=True)
    )
    video = np.frombuffer(video_stream, np.uint8).reshape([-1, params.INPUT_HEIGHT, params.INPUT_WIDTH, 3])

    # predict transitions using the neural network
    predictions = net.predict_video(video)

    # Generate list of scenes from predictions, returns tuples of (start frame, end frame)
    scenes = scenes_from_predictions(predictions, threshold=0.1)
    with open(f"{folder_path}.txt", 'w') as f:
        for sc in scenes:
            f.write(str(sc) + '\n')

    cam = cv2.VideoCapture(video_path)
    currentframe = 0
    index = 0

    while True:
        ret,frame = cam.read() 
        if ret:
            currentframe += 1
            # for sc in scenes:                        
            idx_first = int(scenes[index][0])
            idx_end = int(scenes[index][1])
            idx_025 = int(scenes[index][0] + (scenes[index][1]-scenes[index][0])/4)
            idx_05 = int(scenes[index][0] + (scenes[index][1]-scenes[index][0])/2)
            idx_075 = int(scenes[index][0] + 3*(scenes[index][1]-scenes[index][0])/4)

            #### First #### 
            if currentframe - 1 == idx_first:
                filename_first = "{}/{:0>6d}.jpg".format(folder_path, idx_first)
                # video_save = cv2.resize(video[idx_first], (1280,720))
                cv2.imwrite(filename_first, frame)

            # #### End ####          
            if currentframe - 1 == idx_end:
                filename_end = "{}/{:0>6d}.jpg".format(folder_path, idx_end)
                # video_save = cv2.resize(video[idx_end], (1280,720))
                cv2.imwrite(filename_end, frame)
                index += 1

            #### 025 ####
            if currentframe - 1 == idx_025:
                filename_025 = "{}/{:0>6d}.jpg".format(folder_path, idx_025)
                # video_save = cv2.resize(video[idx_025], (1280,720))
                cv2.imwrite(filename_025, frame)

            # #### 05 ####
            if currentframe - 1 == idx_05:
                filename_05 = "{}/{:0>6d}.jpg".format(folder_path, idx_05)
                # video_save = cv2.resize(video[idx_05], (1280,720))
                cv2.imwrite(filename_05, frame)

            # #### 075 ####
            if currentframe - 1 == idx_075:
                filename_075 = "{}/{:0>6d}.jpg".format(folder_path, idx_075)
                # video_save = cv2.resize(video[idx_075], (1280,720))
                cv2.imwrite(filename_075, frame)

        else:
            break

    cam.release()
    cv2.destroyAllWindows()
# Out:
# Skip C02_V0200
# Skip C02_V0201
# Skip C02_V0202
# Skip C02_V0203
# Skip C02_V0204
# Skip C02_V0205
# Skip C02_V0206
# Skip C02_V0207
# Skip C02_V0208
# Skip C02_V0209
# Skip C02_V0210
# Skip C02_V0211
# Skip C02_V0212
# Skip C02_V0213
# Skip C02_V0214
# Skip C02_V0215
# Skip C02_V0216
# Skip C02_V0217
# Skip C02_V0218
# Skip C02_V0219
# Skip C02_V0220
# Skip C02_V0221
# Skip C02_V0222
# Skip C02_V0223
# Skip C02_V0224
# Skip C02_V0225
# Skip C02_V0226
# Skip C02_V0227
# Skip C02_V0228
# Skip C02_V0229
# Skip C02_V0230
# Skip C02_V0231
# Skip C02_V0232
# Skip C02_V0233
# Skip C02_V0234
# Skip C02_V0235
# Skip C02_V0236
# Skip C02_V0237
# Skip C02_V0238
# Skip C02_V0239
# Skip C02_V0240
# Skip C02_V0241
# Skip C02_V0242
# Skip C02_V0243
# Skip C02_V0244
# 246
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0246.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-29T23:59:12.000000Z
#   Duration: 00:47:00.02, start: 0.000000, bitrate: 1865 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1733 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-29T23:59:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/29/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-29T23:59:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/29/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-29T23:59:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/29/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=84600 fps=1054 q=-0.0 Lsize=  321216kB time=00:47:00.00 bitrate= 933.1kbits/s speed=35.1x
# video:321216kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 84600/84600
# 247
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0247.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-29T05:45:55.000000Z
#   Duration: 00:54:47.74, start: 0.000000, bitrate: 1866 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1734 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-29T05:45:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-29T05:45:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-29T05:45:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=98632 fps=1493 q=-0.0 Lsize=  374493kB time=00:54:47.73 bitrate= 933.1kbits/s speed=49.8x
# video:374493kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 98632/98632
# 248
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0248.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-28T04:12:20.000000Z
#   Duration: 01:02:34.97, start: 0.000000, bitrate: 1270 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1139 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-28T04:12:20.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/27/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-28T04:12:20.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/27/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-28T04:12:20.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/27/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=112649 fps=826 q=-0.0 Lsize=  427714kB time=01:02:34.96 bitrate= 933.1kbits/s speed=27.5x
# video:427714kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 112649/112649
# 249
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0249.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-27T08:50:03.000000Z
#   Duration: 00:53:45.04, start: 0.000000, bitrate: 1762 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1631 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-27T08:50:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/27/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-27T08:50:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/27/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-27T08:50:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/27/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=96751 fps=835 q=-0.0 Lsize=  367351kB time=00:53:45.03 bitrate= 933.1kbits/s speed=27.8x
# video:367351kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 96751/96751
# 250
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0250.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-25T23:46:04.000000Z
#   Duration: 00:50:50.01, start: 0.000000, bitrate: 1539 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1408 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-25T23:46:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/25/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-25T23:46:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/25/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-25T23:46:04.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/25/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=91500 fps=819 q=-0.0 Lsize=  347414kB time=00:50:50.00 bitrate= 933.1kbits/s speed=27.3x
# video:347414kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 91500/91500
# 251
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0251.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-28T11:56:59.000000Z
#   Duration: 00:57:10.01, start: 0.000000, bitrate: 1692 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1561 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-28T11:56:59.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-28T11:56:59.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-28T11:56:59.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/28/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=102900 fps=851 q=-0.0 Lsize=  390698kB time=00:57:10.00 bitrate= 933.1kbits/s speed=28.4x
# video:390698kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 102900/102900
# 252
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0252.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-07T03:17:35.000000Z
#   Duration: 00:47:05.01, start: 0.000000, bitrate: 1493 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1361 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-07T03:17:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/06/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-07T03:17:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/06/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-07T03:17:35.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/06/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=84750 fps=818 q=-0.0 Lsize=  321785kB time=00:47:05.00 bitrate= 933.1kbits/s speed=27.3x
# video:321785kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 84750/84750
# Skip C02_V0253
# 254
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0254.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-05T04:09:43.000000Z
#   Duration: 00:50:40.07, start: 0.000000, bitrate: 1457 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1326 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-05T04:09:43.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/04/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-05T04:09:43.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/04/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-05T04:09:43.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/04/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=91202 fps=824 q=-0.0 Lsize=  346283kB time=00:50:40.06 bitrate= 933.1kbits/s speed=27.5x
# video:346283kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 91202/91202
# 255
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0255.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-04T01:26:38.000000Z
#   Duration: 01:00:35.08, start: 0.000000, bitrate: 1442 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1310 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-04T01:26:38.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/03/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-04T01:26:38.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/03/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-04T01:26:38.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/03/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=109052 fps=842 q=-0.0 Lsize=  414057kB time=01:00:35.06 bitrate= 933.1kbits/s speed=28.1x
# video:414057kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 109052/109052
# 256
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0256.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-02T22:07:37.000000Z
#   Duration: 00:53:03.48, start: 0.000000, bitrate: 1559 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1428 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-02T22:07:37.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/02/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-02T22:07:37.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/02/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-02T22:07:37.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/02/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=95504 fps=837 q=-0.0 Lsize=  362617kB time=00:53:03.46 bitrate= 933.1kbits/s speed=27.9x
# video:362617kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 95504/95504
# 257
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0257.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-02T03:33:26.000000Z
#   Duration: 00:45:15.02, start: 0.000000, bitrate: 1488 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1357 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-02T03:33:26.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/01/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-02T03:33:26.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/01/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-02T03:33:26.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 05/01/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=81450 fps=837 q=-0.0 Lsize=  309255kB time=00:45:15.00 bitrate= 933.1kbits/s speed=27.9x
# video:309255kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 81450/81450
# 258
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0258.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-05-01T00:42:55.000000Z
#   Duration: 00:47:55.00, start: 0.000000, bitrate: 1553 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1422 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-01T00:42:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2022-05-01T00:42:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-05-01T00:42:55.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/30/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=86250 fps=836 q=-0.0 Lsize=  327480kB time=00:47:55.00 bitrate= 933.1kbits/s speed=27.9x
# video:327480kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 86250/86250
# 259
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0259.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-04-30T05:23:03.000000Z
#   Duration: 01:01:54.94, start: 0.000000, bitrate: 1416 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1284 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-04-30T05:23:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/29/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-04-30T05:23:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/29/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-04-30T05:23:03.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/29/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=111448 fps=844 q=-0.0 Lsize=  423154kB time=01:01:54.93 bitrate= 933.1kbits/s speed=28.1x
# video:423154kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 111448/111448
# 260
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0260.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-04-28T13:53:28.000000Z
#   Duration: 00:52:20.01, start: 0.000000, bitrate: 1463 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1332 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-04-28T13:53:28.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/28/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-04-28T13:53:28.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/28/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-04-28T13:53:28.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 04/28/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=94200 fps=835 q=-0.0 Lsize=  357666kB time=00:52:20.00 bitrate= 933.1kbits/s speed=27.8x
# video:357666kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 94200/94200
# 261
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0295.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-03-30T05:52:34.000000Z
#   Duration: 00:51:25.00, start: 0.000000, bitrate: 1573 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1442 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-30T05:52:34.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/29/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-03-30T05:52:34.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/29/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-30T05:52:34.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/29/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=92550 fps=2842 q=-0.0 Lsize=  351401kB time=00:51:25.00 bitrate= 933.1kbits/s speed=94.7x
# video:351401kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 92550/92550
# 296
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0296.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-03-29T12:20:24.000000Z
#   Duration: 01:08:05.02, start: 0.000000, bitrate: 1334 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1202 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-29T12:20:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/29/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-03-29T12:20:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/29/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-29T12:20:24.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/29/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=122550 fps=2904 q=-0.0 Lsize=  465307kB time=01:08:05.00 bitrate= 933.1kbits/s speed=96.8x
# video:465307kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 122550/122550
# 297
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0297.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-03-28T02:20:11.000000Z
#   Duration: 00:51:30.04, start: 0.000000, bitrate: 1720 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1588 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-28T02:20:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/27/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-03-28T02:20:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/27/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-28T02:20:11.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/27/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=92701 fps=2780 q=-0.0 Lsize=  351974kB time=00:51:30.03 bitrate= 933.1kbits/s speed=92.7x
# video:351974kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 92701/92701
# 298
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0298.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-03-26T14:53:53.000000Z
#   Duration: 01:48:25.00, start: 0.000000, bitrate: 950 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 819 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-26T14:53:53.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-03-26T14:53:53.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-26T14:53:53.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/26/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=195150 fps=2937 q=-0.0 Lsize=  740960kB time=01:48:25.00 bitrate= 933.1kbits/s speed=97.9x
# video:740960kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 195150/195150
# 299
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/media/nhattuong/Data/Dataset_BTC/Videos_Batch3/VideoC02_V02/C02_V0299.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2022-03-26T00:46:48.000000Z
#   Duration: 00:55:05.08, start: 0.000000, bitrate: 1642 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 1510 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-26T00:46:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/25/2022.
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       creation_time   : 2022-03-26T00:46:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/25/2022.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> rawvideo (native))
# Press [q] to stop, [?] for help
# Output #0, rawvideo, to 'pipe:':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: rawvideo (RGB[24] / 0x18424752), rgb24, 48x27 [SAR 1:1 DAR 16:9], q=2-31, 933 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2022-03-26T00:46:48.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/25/2022.
#       encoder         : Lavc57.107.100 rawvideo
# frame=99152 fps=2849 q=-0.0 Lsize=  376468kB time=00:55:05.06 bitrate= 933.1kbits/s speed=  95x
# video:376468kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000000%
# [TransNet] Processing video frames 99152/99152

# %%
# For ilustration purposes, we show only 200 frames starting with frame number 8000.
# draw_video_with_predictions(video[8000:8200], predictions[8000:8200], threshold=0.1)

# %%
# draw_video_with_predictions(video[:], predictions[:], threshold=0.1)

# %%
# Generate list of scenes from predictions, returns tuples of (start frame, end frame)
scenes = scenes_from_predictions(predictions, threshold=0.1)

# For ilustration purposes, only the visualized scenes are shown.
# scenes
